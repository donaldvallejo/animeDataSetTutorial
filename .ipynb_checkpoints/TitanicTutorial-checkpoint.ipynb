# %%
import numpy as np
import pandas as pd

# %%
PATH = "anime_list.csv"

df = pd.read_csv(PATH)

# %%
df.head()
# Out:
#    mal_id                            title  \
# 0       1                     Cowboy Bebop
# 1       5  Cowboy Bebop: Tengoku no Tobira
# 2       6                           Trigun
# 3       7               Witch Hunter Robin
# 4       8                   Bouken Ou Beet
#
#                                             synopsis background  \
# 0  In the year 2071, humanity has colonized sever...          -
# 1  Another day, another bounty—such is the life o...          -
# 2  Vash the Stampede is the man with a $$60,000,0...          -
# 3  Witches are individuals with special powers li...          -
# 4  It is the dark century and the people are suff...          -
#
#                           aired  airing       duration  episodes   type  \
# 0   Apr 3, 1998 to Apr 24, 1999       0  24 min per ep        26     TV
# 1                   Sep 1, 2001       0    1 hr 55 min         1  Movie
# 2   Apr 1, 1998 to Sep 30, 1998       0  24 min per ep        26     TV
# ...

# %%
df.hist(column="score")
# Out:
# array([[<AxesSubplot:title={'center':'score'}>]], dtype=object)

# %%
df.hist(column="episodes")
# Out:
# array([[<AxesSubplot:title={'center':'episodes'}>]], dtype=object)

# %%
arg_one_piece = (df["title"] == "One Piece")

# %%
df[arg_one_piece]
# Out:
#     mal_id      title                                           synopsis  \
# 11      21  One Piece  Gol D. Roger was known as the "Pirate King," t...
#
#    background              aired  airing duration  episodes type  favorites  \
# 11          -  Oct 20, 1999 to ?       1   24 min        -1   TV     119216
#
#     ...  score  scored_by                     rating  premiered  \
# 11  ...   8.55     841457  PG-13 - Teens 13 or older  Fall 1999
#
#                                                genres  \
# 11  Action, Adventure, Comedy, Super Power, Drama,...
#
#                                               related            status  \
# 11  {'Adaptation': [{'mal_id': 13, 'type': 'manga'...  Currently Airing
#
#                           licensors               producers         studios
# 11  Funimation, 4Kids Entertainment  Fuji TV, TAP, Shueisha  Toei Animation
#
# [1 rows x 23 columns]

# %%
df[df["title"] == "One Piece"]
# Out:
#     mal_id      title                                           synopsis  \
# 11      21  One Piece  Gol D. Roger was known as the "Pirate King," t...
#
#    background              aired  airing duration  episodes type  favorites  \
# 11          -  Oct 20, 1999 to ?       1   24 min        -1   TV     119216
#
#     ...  score  scored_by                     rating  premiered  \
# 11  ...   8.55     841457  PG-13 - Teens 13 or older  Fall 1999
#
#                                                genres  \
# 11  Action, Adventure, Comedy, Super Power, Drama,...
#
#                                               related            status  \
# 11  {'Adaptation': [{'mal_id': 13, 'type': 'manga'...  Currently Airing
#
#                           licensors               producers         studios
# 11  Funimation, 4Kids Entertainment  Fuji TV, TAP, Shueisha  Toei Animation
#
# [1 rows x 23 columns]
